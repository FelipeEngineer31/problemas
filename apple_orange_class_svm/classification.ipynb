# %% [markdown]
# #### Lendo a base de dados

# %%
import pandas as pd

# Load the CSV file with a semicolon delimiter and custom column names
df = pd.read_csv('apple_orange_class_svm/apples_and_oranges.csv')

# Display the first few rows of the DataFrame
df.head()
# Out:
#    Weight  Size   Class
# 0      69  4.39  orange
# 1      69  4.21  orange
# 2      65  4.09  orange
# 3      72  5.85   apple
# 4      67  4.70  orange

# %% [markdown]
# #### Treinando o modelo utilizando SVM

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.model_selection import train_test_split


# Split the data into training and testing sets
X = df[['Weight', 'Size']]
y = df['Class']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Create an SVM classifier object
clf = svm.SVC(kernel='linear')

# Train the classifier using the training data
clf.fit(X_train, y_train)

# Predict the classes of the testing data
y_pred = clf.predict(X_test)

# Evaluate the performance of the classifier using accuracy score
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy:', accuracy)
# Out:
# Accuracy: 1.0

# %% [markdown]
# #### Verificando os valores no grafico

# %%
plt.scatter(X['Weight'], X['Size'], c=np.where(y == 'orange', 'orange', 'red'), cmap=plt.cm.coolwarm)
plt.xlabel('Weight')
plt.ylabel('Size')
plt.title('SVM Classifier')
plt.show()
# Out:
# /tmp/ipykernel_6321/1698107083.py:1: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X['Weight'], X['Size'], c=np.where(y == 'orange', 'orange', 'red'), cmap=plt.cm.coolwarm)

# %% [markdown]
# #### Testando

# %%
data = [69,4.39]
clf.predict([data])
plt.scatter(X['Weight'], X['Size'], c=np.where(y == 'orange', 'orange', 'red'), cmap=plt.cm.coolwarm)
plt.scatter(data[0], data[1], c='blue', marker='o')
plt.xlabel('Weight')
plt.ylabel('Size')
plt.title('SVM Classifier')
plt.show()
# Out:
# /home/codespace/.local/lib/python3.10/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# /tmp/ipykernel_6321/457302735.py:3: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X['Weight'], X['Size'], c=np.where(y == 'orange', 'orange', 'red'), cmap=plt.cm.coolwarm)

# %% [markdown]
# #### Testando

# %%
data = [72,5.85]
clf.predict([data])
plt.scatter(X['Weight'], X['Size'], c=np.where(y == 'orange', 'orange', 'red'), cmap=plt.cm.coolwarm)
plt.scatter(data[0], data[1], c='blue', marker='o')
plt.xlabel('Weight')
plt.ylabel('Size')
plt.title('SVM Classifier')
plt.show()
# Out:
# /home/codespace/.local/lib/python3.10/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# /tmp/ipykernel_6321/1794277460.py:3: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X['Weight'], X['Size'], c=np.where(y == 'orange', 'orange', 'red'), cmap=plt.cm.coolwarm)
